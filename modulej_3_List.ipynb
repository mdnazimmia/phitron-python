# %% [markdown]
# ## List

# %%
# List is mutable
numbers  = [90, 30, 80, 200, 140, 12]
floating = [10.2, 30.32, 89.122, 9.99, 4,89]
fruit = ["Mango", "Banana", "Orange", "Lichi"]
mix = ["Mango", 10.2, 200]

list_er_vetor_list = [[100, 120, 200], [33, 42, 89], [13, 20, 30]]

print(list_er_vetor_list[0][2])

# %%
#access
print(numbers)

print(numbers[2])

numbers[2] = 55 # muitable, we have changed in "0" index = 80 to 55
print(numbers[2])
# Out:
# [90, 30, 55, 200, 140, 12]
# 55
# 55

# %%
# Modification

## adding a number
numbers.append(99)
print(numbers)

# add in a fixed index
numbers.insert(0,111)
print(numbers)

#deleting
# remove from end of the list
numbers.pop()
print(numbers)

#remove a fixed define number
numbers.remove(200)
print(numbers)
# Out:
# [90, 30, 80, 200]
# [90, 30, 80]

# %%
numbers = [10, 32, 90, 28, 100, 100, 5 , 100]
print(numbers)

numbers.reverse()
print(numbers)
# Out:
# [10, 32, 90, 28, 100, 100, 5, 100]
# [100, 5, 100, 100, 28, 90, 32, 10]

# %%
numbers.sort()
print(numbers)


numbers.sort(reverse=True)
print(numbers)
# Out:
# [5, 10, 28, 32, 90, 100, 100, 100]
# [100, 100, 100, 90, 32, 28, 10, 5]

# %% [markdown]
#  ## Stack as List

# %%
stack = []

# Stack a push
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)

# Getting the top element
#print(stack.pop())
#print(stack.pop())
#print(stack.pop())
#print(stack.pop())
#print(stack.pop())

print(stack.pop())

# access the first element
print(f"In front {stack[-1]}\n")

print(stack.pop())
print(f"In front {stack[-1]}\n")
# Out:
# 5
# In front 4
#
# 4
# In front 3

# %% [markdown]
# ## List as Queue

# %%
queue = []

#push on queue

#queue.append(1)
#queue.append(2)
#queue.append(3)
#queue.append(4)
#queue.append(5)


#remove
print(queue.pop(0))

#accessing the front element
print(f"In front {queue [0]}")

queue.pop(0)

print(f"in front {queue [0]}")
# Out:
# 1
# In front 2
# in front 3
