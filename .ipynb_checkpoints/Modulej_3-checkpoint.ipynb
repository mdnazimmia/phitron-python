# %%
print("Hello world")
# Out:
# Hello world

# %%
prompt = "What is your name?"
print(prompt)
# Out:
# What is your name?

# %%
message = """tell me about yourself ?
Are you faccing every problem with code ?
How are you tackling them
"""
print(message)
# Out:
# tell me about yourself ?
# Are you faccing every problem with code ?
# How are you tackling them

# %% [markdown]
# ## Indexing and Slicing

# %%
string = "Hello wrold"
print(string[7])
# Out:
# r

# %%
first_message = message[0:24]
print(first_message)

new_first_message = first_message[::-1]
print(new_first_message)
# Out:
# tell me about yourself ?

# %%
print(first_message[-1])
print(first_message[-2])
print(first_message[-3])
print(first_message[-4])
print(first_message[-5])
print(first_message[-6])
# Out:
# ?
#
# f
# l
# e
# s

# %% [markdown]
# ## String Method

# %%
## String is immutalbe is not possible to change anything after declar

string ="Welcome to Phitron ML Course in, phitron ML to ML to ML"

#process_strings = string.upper()
#process_strings = string.capitalize()
process_strings = string.lower()

print(process_strings)
#Length
print(len(string))

# word ase kina -> bool
print("Phitron" in string)

# Shurur kon index theke substring ta shuru hoise

shuru_index = process_strings.find("phitron")
print(shuru_index)

#Sesher kon index theke substring ta shuru hoise

sesher_index = process_strings.rfind("phitron")
print(sesher_index)


# Substring koi bar ache
count = process_strings.count("to")
print(count)

# replace a substring

process_string = string.replace("ML", "AI/ML")
print(process_string)
# Out:
# welcome to phitron ml course in, phitron ml to ml to ml
# 55
# True
# 11
# 33
# 3
# Welcome to Phitron AI/ML Course in, phitron AI/ML to AI/ML to AI/ML

# %%
string = "Welcome to Phitron ML Course , Phitron"
print(string)
# Out:
# Welcome to Phitron ML Course , Phitron

# %% [markdown]
# ## Spliting, Joining , Formatted String

# %%
prompt = "Where are you from ?"
token = prompt.split()

print(token)

sentence = "-".join(token)
print(sentence)
# Out:
# ['Where', 'are', 'you', 'from', '?']
# Where-are-you-from-?

# %%
name = "Abdul Noor"
age = 7
height = 4.320892

bio =(f"He is {name.upper()}, also {age} year old and he is {height:.3} ft tall\n")
print(bio)

model_accuracy = 0.83238907
print(f"The model accuracy is {model_accuracy:.2%} given")
# Out:
# He is ABDUL NOOR, also 7 year old and he is 4.32 ft tall
#
# The model accuracy is 83.24% given

# %% [markdown]
# ## Formatting

# %% [markdown]
# ## List

# %%
## List is muttable , change is possible after define anything
number = [100, 200, 30, 89, 12, 138]

# %%
print(number[2])

number[2] = 90 # immutable , index 2 = 30 but we have changed into 90

print(number[2])
# Out:
# 30
# 90
