# %% [markdown]
# ## Function def

# %%
def sum_function(a,b):
    sum = a + b
    print(sum)

sum_function(20,20)
sum_function(12,12)

def my_function():
    print("From first input")
    print("Second one is also there")

my_function()
# Out:
# 40
# 24
# From first input
# Second one is also there

# %%
def greetings():
    print('Good morning')

    return  1
result = greetings()
print(result)
# Out:
#   Cell In[5], line 4
#     return = 1
#            ^
# SyntaxError: invalid syntax
